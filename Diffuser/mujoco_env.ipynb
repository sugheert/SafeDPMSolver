# %%
import gym
import d4rl  # <-- THIS registers maze2d environments
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# c:\Users\Owner\anaconda3\envs\py_3_10\lib\site-packages\Cython\Distutils\old_build_ext.py:14: DeprecationWarning: dep_util is Deprecated. Use functions from setuptools instead.
#   from distutils.dep_util import newer, newer_group
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 import gym
# ----> 2 import d4rl  # <-- THIS registers maze2d environments
#
# File c:\Users\Owner\anaconda3\envs\py_3_10\lib\site-packages\d4rl\__init__.py:14
# ...

# %%
env = gym.make("maze2d-umaze-v1")
dataset = env.get_dataset()
# Out:
# ---------------------------------------------------------------------------
# NameNotFound                              Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 env = gym.make("maze2d-umaze-v1")
#       2 dataset = env.get_dataset()
#
# File c:\Users\Owner\anaconda3\envs\py_3_10\lib\site-packages\gymnasium\envs\registration.py:681, in make(id, max_episode_steps, disable_env_checker, **kwargs)
#     678     assert isinstance(id, str)
#     680     # The environment name can include an unloaded module in "module:env_name" style
# --> 681     env_spec = _find_spec(id)
#     683 assert isinstance(env_spec, EnvSpec)
#     685 # Update the env spec kwargs with the `make` kwargs
#
# File c:\Users\Owner\anaconda3\envs\py_3_10\lib\site-packages\gymnasium\envs\registration.py:526, in _find_spec(env_id)
#     520     logger.warn(
#     521         f"Using the latest versioned environment `{new_env_id}` "
# ...
